# %% [markdown]
# <a href="https://colab.research.google.com/github/fazafi/apaya/blob/main/Tugas_Akhir_Kelompok_11_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings; warnings.simplefilter('ignore')
import nltk

try:
    import google.colab
    IN_COLAB = True
    # !wget https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataDDGsna.py
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/contoh.pdf
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/slang.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_id.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_en.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/kata_dasar.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-ind-def.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-msa-all.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/ind_SA.csv
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/all_indo_man_tag_corpus_model.crf.tagger

    # !pip install --upgrade spacy python-crfsuite unidecode textblob sastrawi sklearn-pycrfsuite
    # !pip install --upgrade unidecode twython tweepy beautifulsoup4 tika
    # !python -m spacy download en
    # !python -m spacy download xx
    # !python -m spacy download en_core_web_sm
    nltk.download('popular')
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# --2022-06-12 05:42:19--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataDDGsna.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8030 (7.8K) [text/plain]
# Saving to: ‘taudataDDGsna.py’
#
# taudataDDGsna.py    100%[===================>]   7.84K  --.-KB/s    in 0s
#
# 2022-06-12 05:42:20 (98.5 MB/s) - ‘taudataDDGsna.py’ saved [8030/8030]
#
# mkdir: cannot create directory ‘data’: File exists
# --2022-06-12 05:42:20--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/contoh.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import warnings; warnings.simplefilter('ignore')
import nltk

try:
    import google.colab
    IN_COLAB = True
    # !wget https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataEDA02CTA.py
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/slang.dic
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/slang.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_id.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/stopwords_en.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/kata_dasar.txt
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-ind-def.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/wn-msa-all.tab
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/ind_SA.csv
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/all_indo_man_tag_corpus_model.crf.tagger

    # !pip install --upgrade spacy python-crfsuite unidecode textblob sastrawi sklearn-pycrfsuite
    # !pip install --upgrade unidecode twython tweepy beautifulsoup4
    # !python -m spacy download xx_ent_wiki_sm
    # !python -m spacy download en_core_web_sm
    nltk.download('popular')
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# --2022-06-12 05:39:28--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/taudataEDA02CTA.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8834 (8.6K) [text/plain]
# Saving to: ‘taudataEDA02CTA.py’
#
# taudataEDA02CTA.py  100%[===================>]   8.63K  --.-KB/s    in 0s
#
# 2022-06-12 05:39:28 (63.1 MB/s) - ‘taudataEDA02CTA.py’ saved [8834/8834]
#
# --2022-06-12 05:39:29--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/slang.dic
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
import taudataDDGsna as tau
import tweepy, json, urllib.request, requests
from urllib.request import Request, urlopen
from twython import TwythonStreamer
from bs4 import BeautifulSoup as bs
from tqdm import tqdm
"Done"
# Out:
# 'Done'

# %%
import taudataEDA02CTA as cta
import json, urllib.request, requests, tweepy
from urllib.request import Request, urlopen
from tqdm import tqdm

"Done"
# Out:
# 'Done'

# %%
# Contoh API Keys (Sesuaikan dengan API keys masing-masing)

Ck = 'ehzQHcPeGSr0J9unF5fDC01WR' # consumer_key
Cs = 'C6ZGUl57pC5YxLdoQzoQUcFQHntTCOAfkbmny5awIaKHqC6HRM' # consumer_secret
At = '1452450825645617154-IUXVqpqSvVfKe5zCwy74QMCUErrll5' # access_token
As = 'V8MKhfbFtuSfwSCXLkq1QNvh7CMf42yUQcDb125YviBOd' # access_secret

'Done'
# Out:
# 'Done'

# %%
#menyambungkan colab dgn twitter
import tweepy 

auth = tweepy.auth.OAuthHandler(Ck, Cs) #authorization
auth.set_access_token(At, As) #authorization
api = tweepy.API(auth, wait_on_rate_limit=True, timeout=180, retry_count=5, retry_delay=3) #parameter
usr_ = api.verify_credentials()
print('Welcome "{}" you are now connected to twitter server'.format(usr_.name))
# Out:
# Welcome "Faza Ilmiyah" you are now connected to twitter server

# %%
qry = 'indonesiamasters2022'
N = 2000 # jumlah N tweet "terkini" yang ingin diambil
T = []
for post in tqdm(tweepy.Cursor(api.search_tweets, q=qry, lang='id', tweet_mode='extended').items(N)):
    T.append(post) #parameter
    
"Done"
# Out:
# 2000it [00:30, 65.46it/s]
# 'Done'

# %%
T[0]._json
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Jun 12 05:55:37 +0000 2022',
#  'display_text_range': [0, 127],
#  'entities': {'hashtags': [{'indices': [73, 81], 'text': 'DIM2022'},
#    {'indices': [82, 103], 'text': 'IndonesiaMasters2022'}],
#   'media': [{'display_url': 'pic.twitter.com/BgGqbKwDSU',
#     'expanded_url': 'https://twitter.com/badmintonupdate/status/1535596980231356416/photo/1',
#     'id': 1535596933808812033,
#     'id_str': '1535596933808812033',
#     'indices': [104, 127],
#     'media_url': 'http://pbs.twimg.com/media/FU-JRn3acAEm90h.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/FU-JRn3acAEm90h.jpg',
#     'sizes': {'large': {'h': 667, 'resize': 'fit', 'w': 1000},
#      'medium': {'h': 667, 'resize': 'fit', 'w': 1000},
#      'small': {'h': 454, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1535596980231356416,
# ...

# %%
tweet = [t._json for t in T]
print(' Berhasil mendapatkan {} tweets'.format(len(tweet)))
# Out:
#  Berhasil mendapatkan 2000 tweets

# %%
# Data pertama
tweet[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Jun 12 05:55:37 +0000 2022',
#  'display_text_range': [0, 127],
#  'entities': {'hashtags': [{'indices': [73, 81], 'text': 'DIM2022'},
#    {'indices': [82, 103], 'text': 'IndonesiaMasters2022'}],
#   'media': [{'display_url': 'pic.twitter.com/BgGqbKwDSU',
#     'expanded_url': 'https://twitter.com/badmintonupdate/status/1535596980231356416/photo/1',
#     'id': 1535596933808812033,
#     'id_str': '1535596933808812033',
#     'indices': [104, 127],
#     'media_url': 'http://pbs.twimg.com/media/FU-JRn3acAEm90h.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/FU-JRn3acAEm90h.jpg',
#     'sizes': {'large': {'h': 667, 'resize': 'fit', 'w': 1000},
#      'medium': {'h': 667, 'resize': 'fit', 'w': 1000},
#      'small': {'h': 454, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1535596980231356416,
# ...

# %%
# Datanya berbentuk JSON
#cari tau tweet pertama dibikin kapan dan tweetnya apa
tweet[0]['created_at'], tweet[0]['full_text']
# Out:
# ('Sun Jun 12 05:55:37 +0000 2022',
#  'RT @badmintonupdate: Taufik Hidayat in the audience.\n\n📸 Badminton Photo\n\n#DIM2022 #IndonesiaMasters2022 https://t.co/BgGqbKwDSU')

# %%
# Contoh mengakses data spesifik pada tweet yang pertama:
print('tweet pertama oleh "{}" : "{}"'.format(tweet[0]['user']['screen_name'],tweet[0]['full_text']))
# Out:
# tweet pertama oleh "werewolfkm" : "RT @badmintonupdate: Taufik Hidayat in the audience.
#
# 📸 Badminton Photo
#
# #DIM2022 #IndonesiaMasters2022 https://t.co/BgGqbKwDSU"

# %%
import json 
def saveTweets(tweets, file='Tweets.json'): #in Json Format
    with open(file, 'w') as f:
        for t in tweets:
            try:
                f.write(json.dumps(t)+'\n')
            except:
                pass

# %%
# Menyimpan hasil crawling twitter
fileName = 'DIM2022.json'
saveTweets(tweet, file=fileName)
print('Saved to '+fileName)
# Out:
# Saved to DIM2022.json

# %%
def loadTweets(file='Tweets.json'):
    f=open(file,encoding='utf-8', errors ='ignore', mode='r')
    T=f.readlines();f.close()
    for i,t in enumerate(T):
        T[i] = json.loads(t.strip())
    return T

# %%
# Me-load kembali jika (misal) analisa ingin dilakukan di lain waktu
# Sengaja nama variabelnya saya bedakan (T2)
T2 = loadTweets(file=fileName)
print('tweet pertama oleh "{}" : "{}"'.format(T2[0]['user']['screen_name'],T2[0]['full_text']))
# Out:
# tweet pertama oleh "werewolfkm" : "RT @badmintonupdate: Taufik Hidayat in the audience.
#
# 📸 Badminton Photo
#
# #DIM2022 #IndonesiaMasters2022 https://t.co/BgGqbKwDSU"

# %%
# Contoh mengambil hanya data tweet
D = [t['full_text'] for t in T2]
D[:5] # 5 tweet pertama
# Out:
# ['RT @badmintonupdate: Taufik Hidayat in the audience.\n\n📸 Badminton Photo\n\n#DIM2022 #IndonesiaMasters2022 https://t.co/BgGqbKwDSU',
#  'RT @ZonaBulutangkis: Congrats to Siwei/Yaqiong!!! DESERVED.\n\n#IndonesiaMasters2022',
#  '3rd time champion title this year! congratulations zheng siwei and huang yaqiong!!! YaSi yyds❤️❤️🏆🥇\n\n#IndonesiaMasters2022 https://t.co/CV0hj3aUFz',
#  'RT @ZonaBulutangkis: Congrats to Siwei/Yaqiong!!! DESERVED.\n\n#IndonesiaMasters2022',
#  'RT @bulutangkisINA: Order of Play Final #IndonesiaMasters2022 dimulai pukul 12:00 WIB. Live di MNC TV dan YouTube BWF TV (pakai VPN USA).…']

# %%
slangFixId = tau.loadCorpus(file = 'data/slang.txt', sep=':')
stopId, _ = tau.LoadStopWords(lang='id')
stopId.add("rt")

list(stopId)[:5]
# Out:
# ['siapapun', 'masa', 'minta', 'ditanya', 'hendaknya']

# %%
from tqdm import tqdm 

cleanD = []
for t in tqdm(D):
    doc = tau.cleanText(t, fix=slangFixId, lan='id', stops = stopId)
    cleanD.append(doc)
    
"Done"
# Out:
# 100%|██████████| 2000/2000 [00:01<00:00, 1434.82it/s]
# 'Done'

# %%
print (D[20])
# Out:
# Huang Yaqiong/Zheng Siwei juara #IndonesiaMasters2022
# Dahlah gak usah di pisah mereka.
# Chemistry mereka masih ok .
# Congratulations !!

# %%
import re

HTfilters = set(['zz', 'architec', 'prize', 'stirli', 'architect', 'london', 'cpd', 'design', 'stirling', 'photogr', 'gemini', 
                 'mule', 'karaoke', 'playing', 'official', 'berita', 'follow', 'retweet', 'mufc', 'ntms', 'infolimit', 'eeaa', 
                 'eaa', 'cfc', 'caprico', 'breaking','news', 'libra', 'mereka', 'brankas', 'psikolog', 'aquarius', 'klc'])
# modifikasi HTfilters sesuai data kamu
HT = {'hashtags':[]}
count = 0
getHashTags = re.compile(r"#(\w+)")
for i, d in tqdm(enumerate(D)):
    hashtags = re.findall(getHashTags, d)
    if hashtags:
        TG = []
        for tag in hashtags:
            dTag = str(tag).strip().lower()
            if len(dTag)>2:
                add = True
                for f in HTfilters:
                    if f in dTag:
                        add=False; break
                if add:
                    TG.append('#'+dTag); count += 1
            HT['hashtags'].append(TG)
print('Found {} number of hashtags'.format(count))
# Out:
# 2000it [00:00, 108746.65it/s]
# Found 2416 number of hashtags

# %%
filename = 'datapreprosessing.txt'
with open(filename, 'w') as f:
    for T in cleanD:
        f.write(T+'\n')
        
"Tweets Saved!"
# Out:
# 'Tweets Saved!'

# %% [markdown]
# ## Visualisasi Hastag

# %%
import pandas as pd

N = 50 # Number of top frequent hashtags to be plotted

dtHT = [x for t in tqdm(HT['hashtags']) for x in t] # any(h not in x for h in HTfilters)
dtHT = pd.Series(dtHT)
dtHT = dtHT.value_counts()
dtHT = dtHT.sort_index()
dtHT = dtHT.sort_values(ascending = False) 
dtHT.to_csv('hashTags_2021.csv', encoding='utf8')
dtHT = dtHT.iloc[:N]

p = dtHT.plot(kind='barh', figsize=(12,8), legend = False)
# Out:
# 100%|██████████| 2422/2422 [00:00<00:00, 775229.26it/s]

# %% [markdown]
# ## Visualisasi Voyant

# %%
# Pengambilan Data dan-atau Loading Data 
qry = "indonesia masters 2022"
tweetFile = 'DIM2022.json'.format(qry)
try:
    data = cta.loadTweets(file=tweetFile)
    print("Local Data loaded, processing {} tweets.".format(len(data)))
except Exception as Err_:
    print("Local data not available, importing data directly from twitter ... ")
    api = cta.connect(key=(Ck, Cs, At, As))
    data = cta.crawlTwitter(api, qry, N=5000)
    cta.saveTweets(data, file=tweetFile) # Save untuk lain waktu
    
tweets = [t['full_text'] for t in data] # Hanya mengambil tweeet saja untuk module ini.
# Out:
# Local Data loaded, processing 2000 tweets.

# %%
stopId, lemmaId = cta.LoadStopWords(lang='id')
slangFixId = cta.loadCorpus(file = 'data/slang.txt', sep=':')

cleaned_data = []
for tweet in tqdm(tweets):
    cleaned_data.append(cta.cleanText(tweet, lemma=lemmaId, lan='id', stops = stopId, fix=slangFixId))
    
cleaned_data[:7]
# Out:
# 100%|██████████| 2000/2000 [03:42<00:00,  8.98it/s]
# ['rt badmintonupdate taufik hidayat in the audience badminton photo indonesia masters',
#  'rt zonabulutangkis congrats to siwei yaqiong deserved indonesia masters',
#  'time champion title this year congratulations zheng siwei and huang yaqiong yasi yyds indonesia masters',
#  'rt zonabulutangkis congrats to siwei yaqiong deserved indonesia masters',
#  'rt bulutangkisina order of play final indonesia masters wib live mnc televisi youtube bwf televisi pakai vpn usa',
#  'tropinya baguss indonesia masters',
#  'rt zonabulutangkis congrats to siwei yaqiong deserved indonesia masters']

# %%
# stopwords
df=open('data/stopwords_id.txt',"r",encoding="utf-8", errors='replace')
id_stop = df.readlines()
df.close()
id_stop = [t.strip().lower() for t in id_stop]

id_stop = set(id_stop)

# %%
id_stop.add('rt')
id_stop.add('nya')
id_stop.add('kah')

# %%
# Save ke txt ... lalu nanti akan di upload ke Voyant Tools
filename = tweetFile.replace(".json", ".txt")
cta.saveTweets(cleaned_data, file=filename, type_="plain")

"Tweets Saved: ".format(filename) # Silahkan cek di folder "Data", pindahkan ke Desktop untukk memudahkan tahap selanjutnya
# Out:
# 'Tweets Saved: '

# %%
from unidecode import unidecode
# Save Raw tweet untuk mendapatkan konteks yang lebih baik
tweets = [unidecode(t) for t in tweets]
cta.saveTweets(tweets, file=filename.replace(".txt", "_tweets.txt"), type_="plain")

# %% [markdown]
# **Cirrus**

# %% [markdown]
# ![S__52133896.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Word Frequencies**

# %% [markdown]
# ![S__52133899.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Terms Berry**

# %% [markdown]
# ![S__52133898.jpg](data:image/jpeg;base64,...)
